# %% [markdown]
# <a href="https://colab.research.google.com/github/mpintoponce/python_utec/blob/main/Modulo03%3AVisualizacion_de_Datos/06.Sesi%C3%B3n_5_Multivariado_%5BSTUDENT_VIEW%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1KaUW3_JAieeY7WVNfoRiTSr2JsaeAcXi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Módulo 3** - Sesión 5:  **Multivariado**
# ## Profesor: Germain Garcia Zanabria
#
# ### Indicaciones
#
# Completa las secciones de código en las que se indique `### Completar`. Siga las instrucciones y proporcione la implementación adecuada en cada caso. Si necesitas ayuda o tienes alguna pregunta, no dudes en levantar la mano para que pueda asistirte.
#
# **Nota:**
# No olvides completar con tu análisis en las secciones: `La interpretación de tu gráfico anterior`.

# %%
#Importar Librerias
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Renombrar el nombre de las columnas
df = df.rename({'survived': 'Sobreviviente','pclass':'ClasePasaje',
                    'sex':'Sexo','age':'Edad',
                    'sibsp': 'HnsEsposo', 'parch':'PadresHijos',
                    'fare': 'Tarifa','embarked':'Embarcacion',
                    'class': 'Clase','who':'Genero','adult_male':'HombreAdulto',
                    'deck': 'Cubierta', 'embark_town': 'LugarEmbarcacion',
                    'alive': 'Vivo','alone':'Solo'}, axis=1)
df
# Out:
#      Sobreviviente  ClasePasaje    Sexo  Edad  HnsEsposo  PadresHijos  \
# 0                0            3    male  22.0          1            0
# 1                1            1  female  38.0          1            0
# 2                1            3  female  26.0          0            0
# 3                1            1  female  35.0          1            0
# 4                0            3    male  35.0          0            0
# ..             ...          ...     ...   ...        ...          ...
# 886              0            2    male  27.0          0            0
# 887              1            1  female  19.0          0            0
# 888              0            3  female   NaN          1            2
# 889              1            1    male  26.0          0            0
# 890              0            3    male  32.0          0            0
#
#       Tarifa Embarcacion   Clase Genero  HombreAdulto Cubierta  \
# ...

# %%
df.dtypes
# Out:
# Sobreviviente          int64
# ClasePasaje            int64
# Sexo                  object
# Edad                 float64
# HnsEsposo              int64
# PadresHijos            int64
# Tarifa               float64
# Embarcacion           object
# Clase               category
# Genero                object
# HombreAdulto            bool
# Cubierta            category
# LugarEmbarcacion      object
# Vivo                  object
# Solo                    bool
# dtype: object

# %% [markdown]
# ## ***I. Método No Gráfico***

# %% [markdown]
# ## **Relación entre dos variables**
#
# ### ***Tabla Cruzada***

# %%
#Creamos una tabla cruzada entre el clase y cubierta
pd.crosstab(df['Clase'], df['Cubierta'], margins = True)

# Margins: Me da el total en columnas y filas
# Out:
# Cubierta   A   B   C   D   E   F  G  All
# Clase
# First     15  47  59  29  25   0  0  175
# Second     0   0   0   4   4   8  0   16
# Third      0   0   0   0   3   5  4   12
# All       15  47  59  33  32  13  4  203

# %%
#Creamos una tabla cruzada entre el clase y cubierta
#agregar margins: devuelve la suma (el tipo depende de las cols)
pd.crosstab(df['### Completar'], df['### Completar'], margins=True)
# Out:
# Cubierta   A   B   C   D   E   F  G  All
# Clase
# First     15  47  59  29  25   0  0  175
# Second     0   0   0   4   4   8  0   16
# Third      0   0   0   0   3   5  4   12
# All       15  47  59  33  32  13  4  203

# %%
#Para normalizar a % se usa normalize= all
pd.crosstab(df['### Completar'], df['### Completar'], normalize='all', margins=True)
# Out:
# Cubierta         A         B        C         D         E         F         G  \
# Clase
# First     0.073892  0.231527  0.29064  0.142857  0.123153  0.000000  0.000000
# Second    0.000000  0.000000  0.00000  0.019704  0.019704  0.039409  0.000000
# Third     0.000000  0.000000  0.00000  0.000000  0.014778  0.024631  0.019704
# All       0.073892  0.231527  0.29064  0.162562  0.157635  0.064039  0.019704
#
# Cubierta       All
# Clase
# First     0.862069
# Second    0.078818
# Third     0.059113
# All       1.000000

# %% [markdown]
# ## **Relación entre variables cuantitativas**
#
# ### ***Covarianza***
#
# *   La función `cov()` calcula la covarianza entre todas las variables cuantitativas

# %%
# Seleccionar solo las columnas numéricas
numeric_df = df.select_dtypes(include=['number'])

# Calcular la matriz de covarianza
cov_matrix = numeric_df.cov()

# Mostrar la matriz de covarianza
cov_matrix
# Out:
#                Sobreviviente  ClasePasaje        Edad  HnsEsposo  PadresHijos  \
# Sobreviviente       0.236772    -0.137703   -0.551296  -0.018954     0.032017
# ClasePasaje        -0.137703     0.699015   -4.496004   0.076599     0.012429
# Edad               -0.551296    -4.496004  211.019125  -4.163334    -2.344191
# HnsEsposo          -0.018954     0.076599   -4.163334   1.216043     0.368739
# PadresHijos         0.032017     0.012429   -2.344191   0.368739     0.649728
# Tarifa              6.221787   -22.830196   73.849030   8.748734     8.661052
#
#                     Tarifa
# Sobreviviente     6.221787
# ClasePasaje     -22.830196
# Edad             73.849030
# HnsEsposo         8.748734
# PadresHijos       8.661052
# Tarifa         2469.436846

# %% [markdown]
# ### ***Correlación***
#
# *   La función `corr()` calcula la correlación entre todas las variables cuantitativas

# %%
numeric_df.corr()
# Out:
#                Sobreviviente  ClasePasaje      Edad  HnsEsposo  PadresHijos  \
# Sobreviviente       1.000000    -0.338481 -0.077221  -0.035322     0.081629
# ClasePasaje        -0.338481     1.000000 -0.369226   0.083081     0.018443
# Edad               -0.077221    -0.369226  1.000000  -0.308247    -0.189119
# HnsEsposo          -0.035322     0.083081 -0.308247   1.000000     0.414838
# PadresHijos         0.081629     0.018443 -0.189119   0.414838     1.000000
# Tarifa              0.257307    -0.549500  0.096067   0.159651     0.216225
#
#                  Tarifa
# Sobreviviente  0.257307
# ClasePasaje   -0.549500
# Edad           0.096067
# HnsEsposo      0.159651
# PadresHijos    0.216225
# Tarifa         1.000000

# %% [markdown]
# ## ***II. Método Gráfico***

# %%
#Se puede cambiar el tamaño de las figuras
sns.set(rc={"figure.figsize":(10, 8)}) #ancho=10, alto=8

# %% [markdown]
# ## **Relación entre una variable *Categóricas* y una variable *Cuantitativa*.**

# %% [markdown]
# ### **Gráfico de Barras**

# %%
#Gráfico de Barras
sns.barplot(data = df, x= 'Clase', y= 'Tarifa', palette = "rainbow")

# Cada barra muestra el promedio de la tarifa por cada clase.
# La Línea de la cada barra es la desviación estandar.
# Out:
# /tmp/ipython-input-14-1269093957.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = df, x= 'Clase', y= 'Tarifa', palette = "rainbow")
# <Axes: xlabel='Clase', ylabel='Tarifa'>

# %%
# Crear un gráfico de barras para visualizar la edad según la clase,
# diferenciando por 'Clase' con diferentes colores.

sns.barplot(data=df, hue= "Clase" , y= "Edad", palette= "rainbow", x= "Clase")
# Out:
# <Axes: xlabel='Clase', ylabel='Edad'>

# %%
# Crear un gráfico de barras que muestra el conteo de cada clase en
# el DataFrame 'df'

sns.countplot(data=df, x= "Clase")
# Out:
# <Axes: xlabel='Clase', ylabel='count'>

# %% [markdown]
# ### **Side-by-side bloxpots**

# %%
# Crear un diagrama de cajas que muestra la distribución de la edad para
# cada clase en el DataFrame 'df'

sns.boxplot(x='Clase',y='Edad',data=df)
# Out:
# <Axes: xlabel='Clase', ylabel='Edad'>

# %%
# Crear un diagrama de cajas para la 'Edad' según la 'Clase', diferenciando
# por 'Cubierta' en el DataFrame 'df' con una paleta de colores 'rainbow'

sns.boxplot(x="Clase",y="Edad",data=df, palette='rainbow', hue='Cubierta')
# Out:
# <Axes: xlabel='Clase', ylabel='Edad'>

# %% [markdown]
# ### **Histograma**

# %%
# Crear un histograma que muestra la distribución de la edad, coloreado por clase,
# con 50 bins

sns.histplot(data=df, x='### Completar',hue='### Completar', bins=50)

# %% [markdown]
# ## **Relación entre dos variables Categóricas**

# %% [markdown]
# ### **Gráfico de Barras Agrupado**

# %%
# Grafico para variables categóricas

# Crear un gráfico de conteo de la variable categórica 'Clase' diferenciando por
# 'Cubierta' con la paleta de colores 'rainbow'

sns.countplot(x="Clase",data=df, hue='Cubierta', palette='rainbow')
# Out:
# <Axes: xlabel='Clase', ylabel='count'>

# %%
# Grafico para variables categóricas

# Crear un gráfico de conteo de la variable categórica 'Clase' diferenciando por
# 'LugarEmbarcacion' con la paleta de colores 'rainbow'
sns.countplot(x="Clase",data=df, hue='LugarEmbarcacion', palette='rainbow')
# Out:
# <Axes: xlabel='Clase', ylabel='count'>

# %%
# Crear un gráfico de conteo de la variable categórica 'Cubierta'
# diferenciando por 'Clase' con la paleta de colores 'rainbow'

sns.countplot(x="Clase", data=df, hue='Cubierta',palette="rainbow")
# Out:
# <Axes: xlabel='Clase', ylabel='count'>

# %% [markdown]
# ## **Relación entre dos o más variables categóricas y una cuantitativa.**

# %% [markdown]
# ### **Gráfica de Barras Agrupado**

# %%
#Gráfico de Barras Agrupado
# Crear un gráfico de barras para mostrar la 'Tarifa' promedio por 'Clase' diferenciando por 'Cubierta' con la paleta de colores 'rainbow'

sns.barplot(data = df, x= 'Clase', y= 'Tarifa',palette='rainbow', hue= "Cubierta")
# Out:
# <Axes: xlabel='Clase', ylabel='Tarifa'>

# %% [markdown]
# ## **Relación entre variables cuantitativas**

# %% [markdown]
# ### **Gráficos de Dispersión**

# %%
### Completar
sns.scatterplot(data=df, x= 'Tarifa', y= 'Edad')
# Out:
# <Axes: xlabel='Tarifa', ylabel='Edad'>

# %%
# Este código utiliza Seaborn para generar un gráfico de dispersión (scatterplot)
# con datos del DataFrame df, donde 'Tarifa' se representa en el eje x,
#  'Edad' en el eje y, y se utiliza 'Clase' para definir los colores
sns.scatterplot(data=df, x= '### Completar', y= '### Completar', hue='Clase')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-29-2060555978.py in <cell line: 0>()
#       2 # con datos del DataFrame df, donde 'Tarifa' se representa en el eje x,
#       3 #  'Edad' en el eje y, y se utiliza 'Clase' para definir los colores
# ----> 4 sns.scatterplot(data=df, x= '### Completar', y= '### Completar', hue='Clase')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# ...

# %%
# Esta línea de código utiliza Seaborn para crear un gráfico de dispersión (scatterplot) utilizando un DataFrame df, donde se representa la columna 'Tarifa' en el eje x, la columna 'Edad' en el eje y, se utiliza la columna 'Vivo' para el estilo de los puntos y la columna 'Clase'
# para diferenciar los colores de los puntos mediante el parámetro hue.

sns.scatterplot(data=df, x= '### Completar', y= '### Completar', style='Vivo', hue='Clase')
# Out:
# <Axes: xlabel='Tarifa', ylabel='Edad'>

# %% [markdown]
# ### **Mapas de Calor**

# %%
# Seleccionar solo las columnas numéricas
numeric_df = df.select_dtypes(include=['number'])

# Calcular la matriz de correlacion
dataCorr = numeric_df.corr()

# Mostrar la matriz de correlacion
dataCorr
# Out:
#                Sobreviviente  ClasePasaje      Edad  HnsEsposo  PadresHijos  \
# Sobreviviente       1.000000    -0.338481 -0.077221  -0.035322     0.081629
# ClasePasaje        -0.338481     1.000000 -0.369226   0.083081     0.018443
# Edad               -0.077221    -0.369226  1.000000  -0.308247    -0.189119
# HnsEsposo          -0.035322     0.083081 -0.308247   1.000000     0.414838
# PadresHijos         0.081629     0.018443 -0.189119   0.414838     1.000000
# Tarifa              0.257307    -0.549500  0.096067   0.159651     0.216225
#
#                  Tarifa
# Sobreviviente  0.257307
# ClasePasaje   -0.549500
# Edad           0.096067
# HnsEsposo      0.159651
# PadresHijos    0.216225
# Tarifa         1.000000

# %%
sns.heatmap( ### Completar)
# Out:
# <Axes: >

# %%
sns.heatmap(### Completar ,cmap = "BuPu")
# Out:
# <Axes: >

# %%
dataCorr
# Out:
#                Sobreviviente  ClasePasaje      Edad  HnsEsposo  PadresHijos  \
# Sobreviviente       1.000000    -0.338481 -0.077221  -0.035322     0.081629
# ClasePasaje        -0.338481     1.000000 -0.369226   0.083081     0.018443
# Edad               -0.077221    -0.369226  1.000000  -0.308247    -0.189119
# HnsEsposo          -0.035322     0.083081 -0.308247   1.000000     0.414838
# PadresHijos         0.081629     0.018443 -0.189119   0.414838     1.000000
# Tarifa              0.257307    -0.549500  0.096067   0.159651     0.216225
#
#                  Tarifa
# Sobreviviente  0.257307
# ClasePasaje   -0.549500
# Edad           0.096067
# HnsEsposo      0.159651
# PadresHijos    0.216225
# Tarifa         1.000000

# %%
sns.boxplot(x='Tarifa',y='LugarEmbarcacion',data=df, palette='rainbow')
# Out:
# <ipython-input-41-289b8608ca88>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Tarifa',y='LugarEmbarcacion',data=df, palette='rainbow')
# <Axes: xlabel='Tarifa', ylabel='LugarEmbarcacion'>

# %%
# Este código utiliza Seaborn para crear un gráfico de caja (`boxplot`) con un DataFrame 'df'.
# Se representa la columna 'Sexo' en el eje x y la columna 'Edad' en el eje y.

sns.boxplot(x='### Completar',y='### Completar',data=df, palette='rainbow', hue='Vivo')
# Out:
# <Axes: xlabel='Sexo', ylabel='Edad'>

# %%
# Se utiliza Seaborn para crear un gráfico de barras (`barplot`) con el DataFrame 'df'.
# En el eje x se representa la columna "Vivo", que posiblemente indica si una persona está viva o no.
# En el eje y se representa la columna "Edad", mostrando la edad de las personas.
#
sns.barplot(data=df, x="### Completar", y= "### Completar", hue="Sexo")
# Out:
# <Axes: xlabel='Vivo', ylabel='Edad'>
