# %% [markdown]
# <a href="https://colab.research.google.com/github/mpintoponce/python_utec/blob/main/Modulo01%3AFundamentos/2.Variables_Expresiones/Variables_Expresiones_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores Aritméticos

# %% [markdown]
# * '+' (suma)
#
# * '-' (resta)
#
# * '*' (multiplicación)
#
# * / (división)
#
# * // (división entera)
#
# * % (módulo)
#
# * ** (potencia)

# %% [markdown]
# **¿Qué hace exactamente módulo?**

# %%
a % b

# %% [markdown]
# Python divide a entre b, pero en lugar del cociente, te devuelve lo que sobra.

# %% [markdown]
# 🧠 ¿Para qué sirve?
#
# 1. Saber si un número es par o impar:

# %%
numero = 8

# %%
if numero % 2 == 0:
    print("Es par")
else:
    print("Es impar")
# Out:
# Es par

# %%
numero = 7
if numero % 2 == 0:
    print("Es par")
else:
    print("Es impar")

# %% [markdown]
# 2. Ejecutar una acción cada cierto número de veces:

# %%
for i in range(1, 11):
    if i % 3 == 0:
        print(i, "es múltiplo de 3")

# %% [markdown]
# 3. Crear patrones o ciclos (por ejemplo, rotar días de la semana):

# %%
dias = ["Lun", "Mar", "Mié", "Jue", "Vie"]
print(dias[7 % 5])  # resultado: "Mié"

# %% [markdown]
# 4. Validaciones bancarias sencillas: Por ejemplo, saber si un número de cuenta termina en un dígito específico.

# %%
cuenta = 123456
if cuenta % 10 == 6:
    print("Número válido")

# %% [markdown]
# ✅ **Ejemplo práctico en evaluación crediticia**
#
# Supongamos que si un cliente tiene un número de cliente cuyo residuo al dividirlo por 3 es 0, recibe un beneficio especial:

# %%
numero_cliente = 108

# %%
if numero_cliente % 3 == 0:
    print("Cliente elegible para bono VIP")
else:
    print("Cliente no elegible")

# %%
numero_cliente = 108
if numero_cliente % 3 == 0:
    print("Cliente elegible para bono VIP")
else:
    print("Cliente no elegible")

# %% [markdown]
# Ejemplo:
#
# Queremos identificar clientes de alto valor basados en:
#
# * Ingreso mensual
# * Años como cliente
# * Cantidad de productos financieros que tiene
# * Cantidad de operaciones fallidas
# * Edad

# %%
ingreso_mensual = 4500

# %%
anios_cliente = 7

# %%
productos = 4

# %%
operaciones_fallidas = 3

# %%
edad = 45

# %%
ingreso_anual = ingreso_mensual * 12

# %%
ingreso_anual
# Out:
# 54000

# %%
bono_fidelidad = anios_cliente ** 2
bono_fidelidad
# Out:
# 49

# %%
bono_fidelidad
# Out:
# 49

# %%
penalidad = operaciones_fallidas * 100
penalidad
# Out:
# 300

# %%
puntaje_base = ingreso_anual / edad
puntaje_base
# Out:
# 1200.0

# %%
puntaje_total = puntaje_base + bono_fidelidad - penalidad + (productos * 250)

# %%
puntaje_total
# Out:
# 1949.0

# %%
segmento = puntaje_total // 100
segmento
# Out:
# 19.0

# %%
es_redondo = puntaje_total % 100 == 0
es_redondo
# Out:
# False

# %%
1 = 2

# %%
1
# Out:
# 1

# %%
type(1)
# Out:
# int

# %%
1 == 2
# Out:
# False

# %%
print("Puntaje total:", round(puntaje_total, 2))
print("Segmento (0 = bajo valor, 1 = medio, 2 o más = alto valor):", int(segmento))
print("¿El puntaje es redondo?", es_redondo)
# Out:
# Puntaje total: 1949.0
# Segmento (0 = bajo valor, 1 = medio, 2 o más = alto valor): 19
# ¿El puntaje es redondo? False

# %%
# Datos de un cliente
ingreso_mensual = 4500 # en dólares
anios_cliente = 7
productos = 4  # tarjetas, cuentas, seguros, etc.
operaciones_fallidas = 3
edad = 45

# Cálculo de puntaje de valor usando operadores aritméticos

# 1. Ingreso anual
ingreso_anual = ingreso_mensual * 12

# 2. Bonificación por fidelidad (años de cliente al cuadrado)
bono_fidelidad = anios_cliente ** 2

# 3. Penalidad por operaciones fallidas (cada una resta 100 puntos)
penalidad = operaciones_fallidas * 100

# 4. Puntaje base (ingreso anual dividido entre edad)
puntaje_base = ingreso_anual / edad

# 5. Puntaje total antes de normalizar
puntaje_total = puntaje_base + bono_fidelidad - penalidad + (productos * 250)

# 6. Normalizamos con división entera entre 100
segmento = puntaje_total // 100

# 7. Usamos módulo para ver si el puntaje es redondo
es_redondo = puntaje_total % 100 == 0

# Resultados
print("Puntaje total:", round(puntaje_total, 2))
print("Segmento (0 = bajo valor, 1 = medio, 2 o más = alto valor):", int(segmento))
print("¿El puntaje es redondo?", es_redondo)

# %% [markdown]
# # Conversión de tipos:
#
# * int()
# * float()
# * str()

# %%
# Solicitar datos al usuario
name = input("Ingrese su nombre: ")  # str: tipo texto
age = int(input("Ingrese su edad: "))   # int: se convierte lo que escribe el usuario a entero
monthly_salary = float(input("Ingrese su ingreso mensual: "))  # float: permite decimales
job_type = input("¿Es trabajador dependiente o independiente? ")  # str

# %%
name = input("Ingrese su nombre: ")
# Out:
# Ingrese su nombre: Monica

# %%
age = int(input("Ingrese su edad: ")) # En este caso recibe la variable como un entero.
# Out:
# Ingrese su edad: 32

# %%
age = input("Ingrese su edad: ") # En este caso lo recibe como un Sring.
# Out:
# Ingrese su edad: 32

# %%
type(age)
# Out:
# str

# %%
monthly_salary = float(input("Ingrese su ingreso mensual: "))
# Out:
# Ingrese su ingreso mensual: 1235.2

# %%
job_type = input("¿Es trabajador dependiente o independiente? ")
# No estamos limitando el código a que ingresen solo dependiente o independiente, sino a que ingresen cualquier dado.
# Out:
# ¿Es trabajador dependiente o independiente? no

# %%
# Datos de una empresa
ingreso_empresa = 4500 # en usd millones
costos_gastos_empresa = 2000 # en usd millones
servicio_deuda = 2000 # en usd millones
deuda_financiera = 8000 # en usd millones
# Cálculo de ratios
# 1. Ebitda
ebitda = ingreso_empresa - costos_gastos_empresa
# 2. Cobertura de deuda
dscr = ebitda / servicio_deuda
# 3. Apalancamiento
apalancamiento = deuda_financiera / ebitda

# Resultados
print("Nivel de Endeudamiento:", round(apalancamiento, 2))
print("Cobertura de Deuda:", round(dscr, 2))

# %% [markdown]
# **🧠 Dato curioso:**
#
# En algunos bancos, el tipo de trabajo (dependiente o independiente) se usa como variable categórica para ajustar la tasa de interés en modelos de riesgo.

# %% [markdown]
# # Funciones integradas:
#
# * round()
# * abs()

# %% [markdown]
# Ejemplo

# %%
bank_loan = 10000

# %%
fraction = 12

# %%
loan_rate = 0.15

# %%
monthly_payment = bank_loan * (1 + loan_rate) / fraction
monthly_payment
# Out:
# 958.3333333333334

# %%
print("Cuota mensual:", round(monthly_payment, 2))
# De esta manera podemos redondear a 2 decimales el resultado anterior.
# Out:
# Cuota mensual: 958.33

# %%
monthly_salary = 1200
print("Puede pagar?", monthly_salary > fraction)
# Out:
# Puede pagar? True

# %%
# Cálculo de cuota mensual con tasa fija
bank_loan = 10000
fraction = 12
loan_rate = 0.15
monthly_payment = bank_loan * (1 + loan_rate) / fraction
print("Cuota mensual:", round(monthly_payment, 2))

# Evaluar si el ingreso alcanza para cubrir la cuota
monthly_salary = 1200
print("Puede pagar?", monthly_salary > monthly_payment)
# Out:
# Cuota mensual: 958.33
# Puede pagar? True

# %% [markdown]
# Ejemplo
#
# Comparar la tasa ofrecida al cliente con la tasa estándar del banco y calcular el spread (diferencia), redondeando el resultado y mostrando su valor absoluto si es negativo.

# %%
# Datos base
standar_rate = 0.105  # 10.5%
client_rate = float(input("Ingrese la tasa ofrecida al cliente (por ejemplo 0.098 para 9.8%): "))

# Cálculo del spread
spread = client_rate - standar_rate
spread_rounded = round(spread, 4)  # redondear a 4 decimales
spread_absolute = abs(spread_rounded)  # valor absoluto del spread

# Mostrar resultado
print("\nTasa estándar del banco:", round(standar_rate * 100, 2), "%")
print("Tasa ofrecida al cliente:", round(client_rate * 100, 2), "%")
print("Diferencia de tasas (spread):", spread_rounded)
print("Valor absoluto del spread:", spread_absolute)
# Out:
# Ingrese la tasa ofrecida al cliente (por ejemplo 0.098 para 9.8%): 0.125
#
# Tasa estándar del banco: 10.5 %
# Tasa ofrecida al cliente: 12.5 %
# Diferencia de tasas (spread): 0.02
# Valor absoluto del spread: 0.02

# %%
# Datos base
standar_rate = 0.105  # 10.5%
client_rate = float(input("Ingrese la tasa ofrecida al cliente (por ejemplo 0.098 para 9.8%): "))

# Cálculo del spread
spread = client_rate - standar_rate
spread_rounded = round(spread, 4)  # redondear a 4 decimales
spread_absolute = abs(spread_rounded)  # valor absoluto del spread

# Mostrar resultado
print("\nTasa estándar del banco:", round(standar_rate * 100, 2), "%") # Se coloca '\n' cuando quiero que el texto agregue un espacio encima de la línea
print("Tasa ofrecida al cliente:", round(client_rate * 100, 2), "%")
print("Diferencia de tasas (spread):", spread_rounded)
print("Valor absoluto del spread:", spread_absolute)
# Out:
# Ingrese la tasa ofrecida al cliente (por ejemplo 0.098 para 9.8%): 0.07
#
# Tasa estándar del banco: 10.5 %
# Tasa ofrecida al cliente: 7.0 %
# Diferencia de tasas (spread): -0.035
# Valor absoluto del spread: 0.035

# %% [markdown]
# **¿Qué hacen round() y abs() aquí?**
#
#
# * round(valor, 4) → redondea el resultado a 4 decimales, útil para porcentajes y precisión en precios.
# * abs(valor) → devuelve el valor positivo de una diferencia, útil para analizar la magnitud del spread sin importar el signo.

# %% [markdown]
# 🧠 **Dato curioso:**
#
# En el mundo bancario, el spread es una de las principales fuentes de ingresos. Aunque parezca pequeño (como 0.0025 o 0.25%), aplicado a millones de dólares genera grandes márgenes. ¡Por eso la precisión en el cálculo es clave!

# %% [markdown]
# # ¿Qué es una lista en Python?

# %% [markdown]
# Una lista es una estructura de datos que permite guardar varios valores dentro de una sola variable.
# Es como una fila de casilleros numerados: cada casillero tiene un valor, y puedes acceder, cambiar o eliminar valores fácilmente.

# %% [markdown]
# **¿Para qué sirve una lista?**

# %% [markdown]
# * Para guardar muchos datos relacionados (como montos de préstamos, edades, tasas de interés, etc.)
# * Para analizar información en bloque, como calcular promedios, contar elementos o buscar tendencias.
# * Para almacenar resultados intermedios o históricos en análisis de datos.

# %% [markdown]
# **¿Qué es el índice?**
#
# El índice es la posición de cada elemento en la lista.
#
# * El índice empieza en 0, no en 1.

# %%
clients = ["Ana", "Luis", "Sofía"] #Lista: Grupo de varios elementos
# Índices:      0       1        2

# %%
clients[0] # Ubica la posición 0 de los elementos de la lista.
# Out:
# 'Ana'

# %%
clients[2]
# Out:
# 'Sofía'

# %%
clients[2] = "Patricia" # De esta manera cambio a alguien de mi lista
clients
# Out:
# ['Ana', 'Luis', 'Patricia']

# %%
clients.append("Miguel") # Agregar a una persona, lo agrega al final.

# %%
clients
# Out:
# ['Ana', 'Luis', 'Patricia', 'Miguel']

# %%
clients.remove("Ana") # Eliminar a una persona, tiene que escribirse el nombre tal y como está en la lista.

# %%
clients
# Out:
# ['Luis', 'Patricia', 'Miguel']

# %%
len(clients) # Cantidad de elementos que hay en nuestra lista.
# Out:
# 3

# %% [markdown]
# **¿Cómo se interpreta una lista?**
#
# Una lista se escribe entre corchetes [] y los valores van separados por comas:

# %%
rates = [0.12, 0.10, 0.09, 0.11]

# %%
rates.append(0.15)

# %%
rates.append(0.12)

# %%
rates.count(0.12)
# Out:
# 2

# %%
rates.index(0.11)
# Out:
# 3

# %%
rates
# Out:
# [0.09, 0.1, 0.11, 0.12, 0.12, 0.15]

# %%
rates.sort()
rates
# Out:
# [0.09, 0.1, 0.11, 0.12, 0.12, 0.15]

# %%
clients.sort() # Si no especificamos, lo ordena de manera alfabética
clients
# Out:
# ['Luis', 'Miguel', 'Patricia']

# %%
clients[2] # Si nosotros manipulamos la lista, cambiaríamos el valor asignado a cada índice.
# Out:
# 'Patricia'

# %% [markdown]
# **¿Cómo se manipulan las listas?**

# %% [markdown]
# ![Screenshot 2025-04-15 at 10.04.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# 1. Historial de pagos de un cliente

# %%
payments = [1, 1, 0, 1, 0]  # 1 = pagó a tiempo, 0 = se atrasó
morosos = payments.count(0)
print("Cantidad de pagos atrasados:", morosos)
# Out:
# Cantidad de pagos atrasados: 2

# %% [markdown]
# 2. Análisis de tasas de préstamos

# %%
rates_2 = [0.12, 0.10, 0.09, 0.11]
average_rates = sum(rates_2) / len(rates_2)
print("Tasa promedio ofrecida:", round(average_rates, 2))
# Out:
# Tasa promedio ofrecida: 0.1

# %% [markdown]
# **🧠 Dato curioso:**
#
# En banca, las listas son la base de muchos modelos: desde scoring crediticio hasta análisis de riesgo. ¡Incluso un modelo de machine learning necesita listas para entrenarse!

# %% [markdown]
# # Estructuras Condicionales I
#
# * Estructura: if, elif, else
#
# * Operadores lógicos: and, or, not
#
# * Jerarquía de decisiones: primero se evalúa not, luego and, y luego or.

# %% [markdown]
# Ejemplo práctico

# %%
ingreso = 2800
edad = 30
historial_morosidad = 1

if ingreso >= 2000 and historial_morosidad == 0:
    print("Recomendado: Crédito personal")
elif ingreso >= 1000 and historial_morosidad <= 1:
    print("Recomendado: Crédito con garantía")
else:
    print("Recomendado: No apto por ahora")
# Out:
# Recomendado: Crédito con garantía

# %% [markdown]
#  **¿Cuál es la diferencia entre elif y else en Python?**
#
# 1. elif (significa “else if” → “si no, pero si…”):
#
# * Evalúa una condición específica, solo si la anterior fue falsa.
# * Puedes tener varios elif seguidos.
# * Cada elif tiene su propia condición.
#
# 2. else (significa “si no…” a secas):
# * Es una opción por defecto, cuando ninguna de las condiciones anteriores se cumple.
# * No tiene condición, es como un "plan B".
#
#
# **Resumen**

# %% [markdown]
# ![Screenshot 2025-04-15 at 10.13.43 PM.png](data:image/png;base64,...)

# %% [markdown]
# # RETO FINAL
#
# **"Simulador de precalificación para crédito hipotecario"**
#
# *Instrucciones:*
#
# Una persona quiere saber si califica para un crédito hipotecario. El sistema debe:
#
# * Pedir el ingreso mensual, edad y el valor del inmueble.
# * Calcular la cuota mensual (crédito a 20 años, tasa fija de 6% anual).
# * Evaluar si la cuota no supera el 30% del ingreso mensual.
# * Validar que la edad + plazo del crédito no supere 70 años.
# * Llevar el historial de evaluaciones realizadas (usando una lista).
# * Mostrar un mensaje con el monto de la cuota, si califica o no, y guardar ese resultado en la lista historial_simulaciones.

# %% [markdown]
# Bibliografía sugerida:
#
# Libro: Automate the Boring Stuff with Python - Al Sweigart (capítulos 2 y 4)
#
# Blog: Real Python
#
# Canal YouTube: Programación ATS, TecnoDavid, HolaMundo
